# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
schools = os.path.join("raw_data", "schools_complete.csv")
students = os.path.join("raw_data", "students_complete.csv")
schools_df = pd.read_csv(schools)
students_df = pd.read_csv(students)

schools_df.head()
# Out:
#    School ID                   name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
students_df.head()
# Out:
#    Student ID               name gender grade             school  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
schools_df = schools_df.rename(columns={"name":"school", "type":"category"})
schools_df.head()
# Out:
#    School ID                 school  category  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
total_students = len(students_df)
print(total_students)
# Out:
# 39170

# %%
avg_math_score = students_df["math_score"].mean()
print(avg_math_score)
# Out:
# 78.98537145774827

# %%
avg_read_score = students_df["reading_score"].mean()
print(avg_read_score)
# Out:
# 81.87784018381414

# %%
total_passing_math = sum(students_df["math_score"] >=70)
print(total_passing_math)
total_percent_passing_math = total_passing_math/total_students*100
print(total_percent_passing_math)
# Out:
# 29370
# 74.9808526934

# %%
total_passing_reading = sum(students_df["reading_score"] >=70)
print(total_passing_reading)
total_percent_passing_reading = total_passing_reading/total_students*100
print(total_percent_passing_reading)
# Out:
# 33610
# 85.8054633648

# %%
overall_passing = (total_percent_passing_reading + total_percent_passing_math) / 2
print(overall_passing)
# Out:
# 80.3931580291

# %%
total_schools = schools_df["school"].nunique()
print(total_schools)
# Out:
# 15

# %%
total_budget = schools_df["budget"].sum()
print(total_budget)
# Out:
# 24649428

# %%
district_summary = pd.DataFrame({"Total Schools":[total_schools],
                             "Total Students":[total_students],
                             "Total Budget":[total_budget],
                             "Average Math Score":[avg_math_score],
                             "Average Reading Score":[avg_read_score],
                             "% Passing Math":[total_percent_passing_math],
                             "% Passing Reading":[total_percent_passing_reading],
                             "Overall Passing Rate":[overall_passing]
})
district_summary
# Out:
#    % Passing Math  % Passing Reading  Average Math Score  \
# 0       74.980853          85.805463           78.985371
#
#    Average Reading Score  Overall Passing Rate  Total Budget  Total Schools  \
# 0               81.87784             80.393158      24649428             15
#
#    Total Students
# 0           39170

# %%
organized_df = district_summary[["Total Schools", "Total Students", "Total Budget", "Average Math Score", 
                                 "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Passing Rate"]]
organized_df.head()
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    Overall Passing Rate
# 0             80.393158

# %%
# 2 STARTS HERE  School Summary

# %%
schools_df["Per Student Budget"] = schools_df["budget"] / schools_df["size"]
schools_df
# Out:
#     School ID                 school  category  size   budget  \
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# 14         14     Thomas High School   Charter  1635  1043130
#
#     Per Student Budget
# 0                655.0
# 1                639.0
# 2                600.0
# 3                652.0
# 4                625.0
# 5                578.0
# 6                582.0
# 7                628.0
# 8                581.0
# 9                609.0
# 10               583.0
# 11               637.0
# 12               650.0
# 13               644.0
# 14               638.0

# %%
schools_avg_math = students_df.groupby('school')["math_score"].mean()
schools_avg_math
# Out:
# school
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
schools_avg_math = schools_avg_math.to_frame().reset_index()
schools_avg_math
# Out:
#                    school  math_score
# 0      Bailey High School   77.048432
# 1     Cabrera High School   83.061895
# 2    Figueroa High School   76.711767
# 3        Ford High School   77.102592
# 4     Griffin High School   83.351499
# 5   Hernandez High School   77.289752
# 6      Holden High School   83.803279
# 7       Huang High School   76.629414
# 8     Johnson High School   77.072464
# 9        Pena High School   83.839917
# 10  Rodriguez High School   76.842711
# 11    Shelton High School   83.359455
# 12     Thomas High School   83.418349
# 13     Wilson High School   83.274201
# 14     Wright High School   83.682222

# %%
schools_avg_math = schools_avg_math.rename(columns={"math_score":"Average Math Score"})
schools_avg_math
# Out:
#                    school  Average Math Score
# 0      Bailey High School           77.048432
# 1     Cabrera High School           83.061895
# 2    Figueroa High School           76.711767
# 3        Ford High School           77.102592
# 4     Griffin High School           83.351499
# 5   Hernandez High School           77.289752
# 6      Holden High School           83.803279
# 7       Huang High School           76.629414
# 8     Johnson High School           77.072464
# 9        Pena High School           83.839917
# 10  Rodriguez High School           76.842711
# 11    Shelton High School           83.359455
# 12     Thomas High School           83.418349
# 13     Wilson High School           83.274201
# 14     Wright High School           83.682222

# %%
schools_df = pd.merge(schools_avg_math, schools_df, on="school")
schools_df
# Out:
#                    school  Average Math Score  School ID  category  size  \
# 0      Bailey High School           77.048432          7  District  4976
# 1     Cabrera High School           83.061895          6   Charter  1858
# 2    Figueroa High School           76.711767          1  District  2949
# 3        Ford High School           77.102592         13  District  2739
# 4     Griffin High School           83.351499          4   Charter  1468
# 5   Hernandez High School           77.289752          3  District  4635
# 6      Holden High School           83.803279          8   Charter   427
# 7       Huang High School           76.629414          0  District  2917
# 8     Johnson High School           77.072464         12  District  4761
# 9        Pena High School           83.839917          9   Charter   962
# 10  Rodriguez High School           76.842711         11  District  3999
# 11    Shelton High School           83.359455          2   Charter  1761
# 12     Thomas High School           83.418349         14   Charter  1635
# 13     Wilson High School           83.274201          5   Charter  2283
# 14     Wright High School           83.682222         10   Charter  1800
#
#      budget  Per Student Budget
# 0   3124928               628.0
# 1   1081356               582.0
# 2   1884411               639.0
# 3   1763916               644.0
# 4    917500               625.0
# 5   3022020               652.0
# 6    248087               581.0
# 7   1910635               655.0
# 8   3094650               650.0
# 9    585858               609.0
# 10  2547363               637.0
# 11  1056600               600.0
# 12  1043130               638.0
# 13  1319574               578.0
# 14  1049400               583.0

# %%
schools_avg_read = students_df.groupby('school')["reading_score"].mean()
schools_avg_read.head()
# Out:
# school
# Bailey High School      81.033963
# Cabrera High School     83.975780
# Figueroa High School    81.158020
# Ford High School        80.746258
# Griffin High School     83.816757
# Name: reading_score, dtype: float64

# %%
schools_avg_read = schools_avg_read.to_frame().reset_index()
schools_avg_read.head()
# Out:
#                  school  reading_score
# 0    Bailey High School      81.033963
# 1   Cabrera High School      83.975780
# 2  Figueroa High School      81.158020
# 3      Ford High School      80.746258
# 4   Griffin High School      83.816757

# %%
schools_avg_read = schools_avg_read.rename(columns={"reading_score":"Average Reading Score"})
#schools_avg_read
schools_avg_read
# Out:
#                    school  Average Reading Score
# 0      Bailey High School              81.033963
# 1     Cabrera High School              83.975780
# 2    Figueroa High School              81.158020
# 3        Ford High School              80.746258
# 4     Griffin High School              83.816757
# 5   Hernandez High School              80.934412
# 6      Holden High School              83.814988
# 7       Huang High School              81.182722
# 8     Johnson High School              80.966394
# 9        Pena High School              84.044699
# 10  Rodriguez High School              80.744686
# 11    Shelton High School              83.725724
# 12     Thomas High School              83.848930
# 13     Wilson High School              83.989488
# 14     Wright High School              83.955000

# %%
schools_df = pd.merge(schools_avg_read, schools_df, on="school")
schools_df.head()
# Out:
#                  school  Average Reading Score  Average Math Score  School ID  \
# 0    Bailey High School              81.033963           77.048432          7
# 1   Cabrera High School              83.975780           83.061895          6
# 2  Figueroa High School              81.158020           76.711767          1
# 3      Ford High School              80.746258           77.102592         13
# 4   Griffin High School              83.816757           83.351499          4
#
#    category  size   budget  Per Student Budget
# 0  District  4976  3124928               628.0
# 1   Charter  1858  1081356               582.0
# 2  District  2949  1884411               639.0
# 3  District  2739  1763916               644.0
# 4   Charter  1468   917500               625.0

# %%
summary_data = pd.merge(schools_df, students_df, on="school")

summary_data.head()
# Out:
#                school  Average Reading Score  Average Math Score  School ID  \
# 0  Bailey High School              81.033963           77.048432          7
# 1  Bailey High School              81.033963           77.048432          7
# 2  Bailey High School              81.033963           77.048432          7
# 3  Bailey High School              81.033963           77.048432          7
# 4  Bailey High School              81.033963           77.048432          7
#
#    category  size   budget  Per Student Budget  Student ID  \
# 0  District  4976  3124928               628.0       17871
# 1  District  4976  3124928               628.0       17872
# 2  District  4976  3124928               628.0       17873
# 3  District  4976  3124928               628.0       17874
# 4  District  4976  3124928               628.0       17875
#
#                   name gender grade  reading_score  math_score
# 0         Blake Martin      M   9th             75          59
# 1         Kathryn Kane      F  12th             84          58
# 2         Richard Haas      M  11th             79          86
# 3          Frank Marsh      M   9th             71          89
# 4  Charles Goodman Jr.      M   9th             90          61

# %%
summary_data = summary_data.replace({"True":1, "False":0})
summary_data["PassMath"] = summary_data['math_score'] > 69
summary_data["PassRead"] = summary_data['reading_score'] > 69
summary_data.head()
# Out:
#                school  Average Reading Score  Average Math Score  School ID  \
# 0  Bailey High School              81.033963           77.048432          7
# 1  Bailey High School              81.033963           77.048432          7
# 2  Bailey High School              81.033963           77.048432          7
# 3  Bailey High School              81.033963           77.048432          7
# 4  Bailey High School              81.033963           77.048432          7
#
#    category  size   budget  Per Student Budget  Student ID  \
# 0  District  4976  3124928               628.0       17871
# 1  District  4976  3124928               628.0       17872
# 2  District  4976  3124928               628.0       17873
# 3  District  4976  3124928               628.0       17874
# 4  District  4976  3124928               628.0       17875
#
#                   name gender grade  reading_score  math_score  PassMath  \
# 0         Blake Martin      M   9th             75          59     False
# 1         Kathryn Kane      F  12th             84          58     False
# 2         Richard Haas      M  11th             79          86      True
# 3          Frank Marsh      M   9th             71          89      True
# 4  Charles Goodman Jr.      M   9th             90          61     False
#
#    PassRead
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %%
passingMath = summary_data[summary_data['math_score'] > 69]
school_population = summary_data['school'].value_counts()
school_passing_math = passingMath.groupby(['school']).count()['name'] / school_population * 100
school_passing_math
# Out:
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# dtype: float64

# %%
test = pd.DataFrame({'% passing_math': school_passing_math})
#schools_df
test.reset_index()
test
# Out:
#                        % passing_math
# Bailey High School          66.680064
# Cabrera High School         94.133477
# Figueroa High School        65.988471
# Ford High School            68.309602
# Griffin High School         93.392371
# Hernandez High School       66.752967
# Holden High School          92.505855
# Huang High School           65.683922
# Johnson High School         66.057551
# Pena High School            94.594595
# Rodriguez High School       66.366592
# Shelton High School         93.867121
# Thomas High School          93.272171
# Wilson High School          93.867718
# Wright High School          93.333333

# %%
test = test.reset_index()
test
# Out:
#                     index  % passing_math
# 0      Bailey High School       66.680064
# 1     Cabrera High School       94.133477
# 2    Figueroa High School       65.988471
# 3        Ford High School       68.309602
# 4     Griffin High School       93.392371
# 5   Hernandez High School       66.752967
# 6      Holden High School       92.505855
# 7       Huang High School       65.683922
# 8     Johnson High School       66.057551
# 9        Pena High School       94.594595
# 10  Rodriguez High School       66.366592
# 11    Shelton High School       93.867121
# 12     Thomas High School       93.272171
# 13     Wilson High School       93.867718
# 14     Wright High School       93.333333

# %%
test = test.rename(columns={"index":"school"})
test.head()
# Out:
#                  school  % passing_math
# 0    Bailey High School       66.680064
# 1   Cabrera High School       94.133477
# 2  Figueroa High School       65.988471
# 3      Ford High School       68.309602
# 4   Griffin High School       93.392371

# %%
schools_df = pd.merge(test, schools_df, on="school")
schools_df.head()
# Out:
#                  school  % passing_math  Average Reading Score  \
# 0    Bailey High School       66.680064              81.033963
# 1   Cabrera High School       94.133477              83.975780
# 2  Figueroa High School       65.988471              81.158020
# 3      Ford High School       68.309602              80.746258
# 4   Griffin High School       93.392371              83.816757
#
#    Average Math Score  School ID  category  size   budget  Per Student Budget
# 0           77.048432          7  District  4976  3124928               628.0
# 1           83.061895          6   Charter  1858  1081356               582.0
# 2           76.711767          1  District  2949  1884411               639.0
# 3           77.102592         13  District  2739  1763916               644.0
# 4           83.351499          4   Charter  1468   917500               625.0

# %%
schools_df = schools_df.rename(columns={"% passing_math":"% Passing Math"})
schools_df
# Out:
#                    school  % Passing Math  Average Reading Score  \
# 0      Bailey High School       66.680064              81.033963
# 1     Cabrera High School       94.133477              83.975780
# 2    Figueroa High School       65.988471              81.158020
# 3        Ford High School       68.309602              80.746258
# 4     Griffin High School       93.392371              83.816757
# 5   Hernandez High School       66.752967              80.934412
# 6      Holden High School       92.505855              83.814988
# 7       Huang High School       65.683922              81.182722
# 8     Johnson High School       66.057551              80.966394
# 9        Pena High School       94.594595              84.044699
# 10  Rodriguez High School       66.366592              80.744686
# 11    Shelton High School       93.867121              83.725724
# 12     Thomas High School       93.272171              83.848930
# 13     Wilson High School       93.867718              83.989488
# 14     Wright High School       93.333333              83.955000
#
#     Average Math Score  School ID  category  size   budget  Per Student Budget
# 0            77.048432          7  District  4976  3124928               628.0
# 1            83.061895          6   Charter  1858  1081356               582.0
# 2            76.711767          1  District  2949  1884411               639.0
# 3            77.102592         13  District  2739  1763916               644.0
# 4            83.351499          4   Charter  1468   917500               625.0
# 5            77.289752          3  District  4635  3022020               652.0
# 6            83.803279          8   Charter   427   248087               581.0
# 7            76.629414          0  District  2917  1910635               655.0
# 8            77.072464         12  District  4761  3094650               650.0
# 9            83.839917          9   Charter   962   585858               609.0
# 10           76.842711         11  District  3999  2547363               637.0
# 11           83.359455          2   Charter  1761  1056600               600.0
# 12           83.418349         14   Charter  1635  1043130               638.0
# 13           83.274201          5   Charter  2283  1319574               578.0
# 14           83.682222         10   Charter  1800  1049400               583.0

# %%
PercentPassRead = summary_data.groupby('school')["PassRead"].sum()
PercentPassRead.head()
# Out:
# school
# Bailey High School      4077.0
# Cabrera High School     1803.0
# Figueroa High School    2381.0
# Ford High School        2172.0
# Griffin High School     1426.0
# Name: PassRead, dtype: float64

# %%
passingRead = summary_data[summary_data['reading_score'] > 69]

# %%
school_population = summary_data['school'].value_counts()
school_passing_read = passingRead.groupby(['school']).count()['name'] / school_population * 100
school_passing_read
# Out:
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# dtype: float64

# %%
school_passing_read = pd.DataFrame({'% passing_read': school_passing_read})
#schools_df
school_passing_read.reset_index()
school_passing_read
# Out:
#                        % passing_read
# Bailey High School          81.933280
# Cabrera High School         97.039828
# Figueroa High School        80.739234
# Ford High School            79.299014
# Griffin High School         97.138965
# Hernandez High School       80.862999
# Holden High School          96.252927
# Huang High School           81.316421
# Johnson High School         81.222432
# Pena High School            95.945946
# Rodriguez High School       80.220055
# Shelton High School         95.854628
# Thomas High School          97.308869
# Wilson High School          96.539641
# Wright High School          96.611111

# %%
school_passing_read = school_passing_read.reset_index()
school_passing_read
# Out:
#                     index  % passing_read
# 0      Bailey High School       81.933280
# 1     Cabrera High School       97.039828
# 2    Figueroa High School       80.739234
# 3        Ford High School       79.299014
# 4     Griffin High School       97.138965
# 5   Hernandez High School       80.862999
# 6      Holden High School       96.252927
# 7       Huang High School       81.316421
# 8     Johnson High School       81.222432
# 9        Pena High School       95.945946
# 10  Rodriguez High School       80.220055
# 11    Shelton High School       95.854628
# 12     Thomas High School       97.308869
# 13     Wilson High School       96.539641
# 14     Wright High School       96.611111

# %%
school_passing_read = school_passing_read.rename(columns={"index":"school"})
school_passing_read.head()
# Out:
#                  school  % passing_read
# 0    Bailey High School       81.933280
# 1   Cabrera High School       97.039828
# 2  Figueroa High School       80.739234
# 3      Ford High School       79.299014
# 4   Griffin High School       97.138965

# %%
schools_df = pd.merge(school_passing_read, schools_df, on="school" )
schools_df
# Out:
#                    school  % passing_read  % Passing Math  \
# 0      Bailey High School       81.933280       66.680064
# 1     Cabrera High School       97.039828       94.133477
# 2    Figueroa High School       80.739234       65.988471
# 3        Ford High School       79.299014       68.309602
# 4     Griffin High School       97.138965       93.392371
# 5   Hernandez High School       80.862999       66.752967
# 6      Holden High School       96.252927       92.505855
# 7       Huang High School       81.316421       65.683922
# 8     Johnson High School       81.222432       66.057551
# 9        Pena High School       95.945946       94.594595
# 10  Rodriguez High School       80.220055       66.366592
# 11    Shelton High School       95.854628       93.867121
# 12     Thomas High School       97.308869       93.272171
# 13     Wilson High School       96.539641       93.867718
# 14     Wright High School       96.611111       93.333333
#
#     Average Reading Score  Average Math Score  School ID  category  size  \
# 0               81.033963           77.048432          7  District  4976
# 1               83.975780           83.061895          6   Charter  1858
# 2               81.158020           76.711767          1  District  2949
# 3               80.746258           77.102592         13  District  2739
# 4               83.816757           83.351499          4   Charter  1468
# 5               80.934412           77.289752          3  District  4635
# 6               83.814988           83.803279          8   Charter   427
# 7               81.182722           76.629414          0  District  2917
# 8               80.966394           77.072464         12  District  4761
# 9               84.044699           83.839917          9   Charter   962
# 10              80.744686           76.842711         11  District  3999
# 11              83.725724           83.359455          2   Charter  1761
# 12              83.848930           83.418349         14   Charter  1635
# 13              83.989488           83.274201          5   Charter  2283
# 14              83.955000           83.682222         10   Charter  1800
#
#      budget  Per Student Budget
# 0   3124928               628.0
# 1   1081356               582.0
# 2   1884411               639.0
# 3   1763916               644.0
# 4    917500               625.0
# 5   3022020               652.0
# 6    248087               581.0
# 7   1910635               655.0
# 8   3094650               650.0
# 9    585858               609.0
# 10  2547363               637.0
# 11  1056600               600.0
# 12  1043130               638.0
# 13  1319574               578.0
# 14  1049400               583.0

# %%
schools_df = schools_df.rename(columns={"% passing_read":"% Passing Reading"})
schools_df.head()
# Out:
#                  school  % Passing Reading  % Passing Math  \
# 0    Bailey High School          81.933280       66.680064
# 1   Cabrera High School          97.039828       94.133477
# 2  Figueroa High School          80.739234       65.988471
# 3      Ford High School          79.299014       68.309602
# 4   Griffin High School          97.138965       93.392371
#
#    Average Reading Score  Average Math Score  School ID  category  size  \
# 0              81.033963           77.048432          7  District  4976
# 1              83.975780           83.061895          6   Charter  1858
# 2              81.158020           76.711767          1  District  2949
# 3              80.746258           77.102592         13  District  2739
# 4              83.816757           83.351499          4   Charter  1468
#
#     budget  Per Student Budget
# 0  3124928               628.0
# 1  1081356               582.0
# 2  1884411               639.0
# 3  1763916               644.0
# 4   917500               625.0

# %%
schools_df["% Overall Passing Rate"] = schools_df[["% Passing Reading","% Passing Math"]].mean(axis=1)
schools_df.head()
# Out:
#                  school  % Passing Reading  % Passing Math  \
# 0    Bailey High School          81.933280       66.680064
# 1   Cabrera High School          97.039828       94.133477
# 2  Figueroa High School          80.739234       65.988471
# 3      Ford High School          79.299014       68.309602
# 4   Griffin High School          97.138965       93.392371
#
#    Average Reading Score  Average Math Score  School ID  category  size  \
# 0              81.033963           77.048432          7  District  4976
# 1              83.975780           83.061895          6   Charter  1858
# 2              81.158020           76.711767          1  District  2949
# 3              80.746258           77.102592         13  District  2739
# 4              83.816757           83.351499          4   Charter  1468
#
#     budget  Per Student Budget  % Overall Passing Rate
# 0  3124928               628.0               74.306672
# 1  1081356               582.0               95.586652
# 2  1884411               639.0               73.363852
# 3  1763916               644.0               73.804308
# 4   917500               625.0               95.265668

# %%
orgSchools_df = schools_df[["school", "category", "size", "Per Student Budget", "Average Math Score", 
                                 "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing Rate"]]
orgSchools_df.head()
# Out:
#                  school  category  size  Per Student Budget  \
# 0    Bailey High School  District  4976               628.0
# 1   Cabrera High School   Charter  1858               582.0
# 2  Figueroa High School  District  2949               639.0
# 3      Ford High School  District  2739               644.0
# 4   Griffin High School   Charter  1468               625.0
#
#    Average Math Score  Average Reading Score  % Passing Math  \
# 0           77.048432              81.033963       66.680064
# 1           83.061895              83.975780       94.133477
# 2           76.711767              81.158020       65.988471
# 3           77.102592              80.746258       68.309602
# 4           83.351499              83.816757       93.392371
#
#    % Passing Reading  % Overall Passing Rate
# 0          81.933280               74.306672
# 1          97.039828               95.586652
# 2          80.739234               73.363852
# 3          79.299014               73.804308
# 4          97.138965               95.265668

# %%
#3 Top Schools by Passing rate
top_schools = orgSchools_df.sort_values("% Overall Passing Rate", ascending=False)
top_schools.head(5)
# Out:
#                  school category  size  Per Student Budget  \
# 1   Cabrera High School  Charter  1858               582.0
# 12   Thomas High School  Charter  1635               638.0
# 9      Pena High School  Charter   962               609.0
# 4   Griffin High School  Charter  1468               625.0
# 13   Wilson High School  Charter  2283               578.0
#
#     Average Math Score  Average Reading Score  % Passing Math  \
# 1            83.061895              83.975780       94.133477
# 12           83.418349              83.848930       93.272171
# 9            83.839917              84.044699       94.594595
# 4            83.351499              83.816757       93.392371
# 13           83.274201              83.989488       93.867718
#
#     % Passing Reading  % Overall Passing Rate
# 1           97.039828               95.586652
# 12          97.308869               95.290520
# 9           95.945946               95.270270
# 4           97.138965               95.265668
# 13          96.539641               95.203679

# %%
#4 Bottom schools by passing rate
bottom_schools = orgSchools_df.sort_values("% Overall Passing Rate", ascending=True)
bottom_schools.head()
# Out:
#                    school  category  size  Per Student Budget  \
# 10  Rodriguez High School  District  3999               637.0
# 2    Figueroa High School  District  2949               639.0
# 7       Huang High School  District  2917               655.0
# 8     Johnson High School  District  4761               650.0
# 3        Ford High School  District  2739               644.0
#
#     Average Math Score  Average Reading Score  % Passing Math  \
# 10           76.842711              80.744686       66.366592
# 2            76.711767              81.158020       65.988471
# 7            76.629414              81.182722       65.683922
# 8            77.072464              80.966394       66.057551
# 3            77.102592              80.746258       68.309602
#
#     % Passing Reading  % Overall Passing Rate
# 10          80.220055               73.293323
# 2           80.739234               73.363852
# 7           81.316421               73.500171
# 8           81.222432               73.639992
# 3           79.299014               73.804308

# %%
#9 Scores by School Type,
category = schools_df.groupby('category')["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing Rate"].mean()
category.head()
# Out:
#           Average Math Score  Average Reading Score  % Passing Math  \
# category
# Charter            83.473852              83.896421       93.620830
# District           76.956733              80.966636       66.548453
#
#           % Passing Reading  % Overall Passing Rate
# category
# Charter           96.586489               95.103660
# District          80.799062               73.673757

# %%
spendingPStudent = schools_df.groupby('Per Student Budget')["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing Rate"].mean()
spendingPStudent.head()
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# Per Student Budget
# 578.0                        83.274201              83.989488       93.867718
# 581.0                        83.803279              83.814988       92.505855
# 582.0                        83.061895              83.975780       94.133477
# 583.0                        83.682222              83.955000       93.333333
# 600.0                        83.359455              83.725724       93.867121
#
#                     % Passing Reading  % Overall Passing Rate
# Per Student Budget
# 578.0                       96.539641               95.203679
# 581.0                       96.252927               94.379391
# 582.0                       97.039828               95.586652
# 583.0                       96.611111               94.972222
# 600.0                       95.854628               94.860875

# %%
spendingPStudent.reset_index(inplace = True)

# %%
spendingPStudent.head()
# Out:
#    Per Student Budget  Average Math Score  Average Reading Score  \
# 0               578.0           83.274201              83.989488
# 1               581.0           83.803279              83.814988
# 2               582.0           83.061895              83.975780
# 3               583.0           83.682222              83.955000
# 4               600.0           83.359455              83.725724
#
#    % Passing Math  % Passing Reading  % Overall Passing Rate
# 0       93.867718          96.539641               95.203679
# 1       92.505855          96.252927               94.379391
# 2       94.133477          97.039828               95.586652
# 3       93.333333          96.611111               94.972222
# 4       93.867121          95.854628               94.860875

# %%
spendingPStudent.columns
# Out:
# Index(['Per Student Budget', 'Average Math Score', 'Average Reading Score',
#        '% Passing Math', '% Passing Reading', '% Overall Passing Rate'],
#       dtype='object')

# %%
bins = [0, 585, 615, 645, 676]
group_names = ['$0-585', '$586-615', '$616-645', '$646-676']

# %%
spendingPStudent["Budget Group"] = pd.cut(spendingPStudent["Per Student Budget"], bins, labels=group_names)
spendingPStudent
# Out:
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 0                578.0           83.274201              83.989488
# 1                581.0           83.803279              83.814988
# 2                582.0           83.061895              83.975780
# 3                583.0           83.682222              83.955000
# 4                600.0           83.359455              83.725724
# 5                609.0           83.839917              84.044699
# 6                625.0           83.351499              83.816757
# 7                628.0           77.048432              81.033963
# 8                637.0           76.842711              80.744686
# 9                638.0           83.418349              83.848930
# 10               639.0           76.711767              81.158020
# 11               644.0           77.102592              80.746258
# 12               650.0           77.072464              80.966394
# 13               652.0           77.289752              80.934412
# 14               655.0           76.629414              81.182722
#
#     % Passing Math  % Passing Reading  % Overall Passing Rate Budget Group
# 0        93.867718          96.539641               95.203679       $0-585
# 1        92.505855          96.252927               94.379391       $0-585
# 2        94.133477          97.039828               95.586652       $0-585
# 3        93.333333          96.611111               94.972222       $0-585
# 4        93.867121          95.854628               94.860875     $586-615
# 5        94.594595          95.945946               95.270270     $586-615
# 6        93.392371          97.138965               95.265668     $616-645
# 7        66.680064          81.933280               74.306672     $616-645
# 8        66.366592          80.220055               73.293323     $616-645
# 9        93.272171          97.308869               95.290520     $616-645
# 10       65.988471          80.739234               73.363852     $616-645
# 11       68.309602          79.299014               73.804308     $616-645
# 12       66.057551          81.222432               73.639992     $646-676
# 13       66.752967          80.862999               73.807983     $646-676
# 14       65.683922          81.316421               73.500171     $646-676

# %%
SpendingPStudent2 = spendingPStudent.groupby('Budget Group')["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing Rate"].mean()
SpendingPStudent2.head()
# Out:
#               Average Math Score  Average Reading Score  % Passing Math  \
# Budget Group
# $0-585                 83.455399              83.933814       93.460096
# $586-615               83.599686              83.885211       94.230858
# $616-645               79.079225              81.891436       75.668212
# $646-676               76.997210              81.027843       66.164813
#
#               % Passing Reading  % Overall Passing Rate
# Budget Group
# $0-585                96.610877               95.035486
# $586-615              95.900287               95.065572
# $616-645              86.106569               80.887391
# $646-676              81.133951               73.649382

# %%
school_size = schools_df.groupby('size')["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing Rate"].mean()
school_size.head()
#schools_df["% Overall Passing Rate"] = schools_df[["% Passing Reading","% Passing Math"]].mean(axis=1)
# Out:
#       Average Math Score  Average Reading Score  % Passing Math  \
# size
# 427            83.803279              83.814988       92.505855
# 962            83.839917              84.044699       94.594595
# 1468           83.351499              83.816757       93.392371
# 1635           83.418349              83.848930       93.272171
# 1761           83.359455              83.725724       93.867121
#
#       % Passing Reading  % Overall Passing Rate
# size
# 427           96.252927               94.379391
# 962           95.945946               95.270270
# 1468          97.138965               95.265668
# 1635          97.308869               95.290520
# 1761          95.854628               94.860875

# %%
school_size.reset_index(inplace = True)
school_size
# Out:
#     level_0  index  size  Average Math Score  Average Reading Score  \
# 0         0      0   427           83.803279              83.814988
# 1         1      1   962           83.839917              84.044699
# 2         2      2  1468           83.351499              83.816757
# 3         3      3  1635           83.418349              83.848930
# 4         4      4  1761           83.359455              83.725724
# 5         5      5  1800           83.682222              83.955000
# 6         6      6  1858           83.061895              83.975780
# 7         7      7  2283           83.274201              83.989488
# 8         8      8  2739           77.102592              80.746258
# 9         9      9  2917           76.629414              81.182722
# 10       10     10  2949           76.711767              81.158020
# 11       11     11  3999           76.842711              80.744686
# 12       12     12  4635           77.289752              80.934412
# 13       13     13  4761           77.072464              80.966394
# 14       14     14  4976           77.048432              81.033963
#
#     % Passing Math  % Passing Reading  % Overall Passing Rate
# 0        92.505855          96.252927               94.379391
# 1        94.594595          95.945946               95.270270
# 2        93.392371          97.138965               95.265668
# 3        93.272171          97.308869               95.290520
# 4        93.867121          95.854628               94.860875
# 5        93.333333          96.611111               94.972222
# 6        94.133477          97.039828               95.586652
# 7        93.867718          96.539641               95.203679
# 8        68.309602          79.299014               73.804308
# 9        65.683922          81.316421               73.500171
# 10       65.988471          80.739234               73.363852
# 11       66.366592          80.220055               73.293323
# 12       66.752967          80.862999               73.807983
# 13       66.057551          81.222432               73.639992
# 14       66.680064          81.933280               74.306672

# %%
school_size.columns
# Out:
# Index(['level_0', 'index', 'size', 'Average Math Score',
#        'Average Reading Score', '% Passing Math', '% Passing Reading',
#        '% Overall Passing Rate'],
#       dtype='object')

# %%
#7 Scores by School Spending BINS
bins = [0, 1000, 2000, 6000]
# Create the names for the four bins
group_names = ['Small(<1000)', 'Medium(1000-2000)', 'Large(2000-5000)']

# %%
school_size["Size Group"] = pd.cut(school_size["size"], bins, labels=group_names)
school_size
# Out:
#     level_0  index  size  Average Math Score  Average Reading Score  \
# 0         0      0   427           83.803279              83.814988
# 1         1      1   962           83.839917              84.044699
# 2         2      2  1468           83.351499              83.816757
# 3         3      3  1635           83.418349              83.848930
# 4         4      4  1761           83.359455              83.725724
# 5         5      5  1800           83.682222              83.955000
# 6         6      6  1858           83.061895              83.975780
# 7         7      7  2283           83.274201              83.989488
# 8         8      8  2739           77.102592              80.746258
# 9         9      9  2917           76.629414              81.182722
# 10       10     10  2949           76.711767              81.158020
# 11       11     11  3999           76.842711              80.744686
# 12       12     12  4635           77.289752              80.934412
# 13       13     13  4761           77.072464              80.966394
# 14       14     14  4976           77.048432              81.033963
#
#     % Passing Math  % Passing Reading  % Overall Passing Rate  \
# 0        92.505855          96.252927               94.379391
# 1        94.594595          95.945946               95.270270
# 2        93.392371          97.138965               95.265668
# 3        93.272171          97.308869               95.290520
# 4        93.867121          95.854628               94.860875
# 5        93.333333          96.611111               94.972222
# 6        94.133477          97.039828               95.586652
# 7        93.867718          96.539641               95.203679
# 8        68.309602          79.299014               73.804308
# 9        65.683922          81.316421               73.500171
# 10       65.988471          80.739234               73.363852
# 11       66.366592          80.220055               73.293323
# 12       66.752967          80.862999               73.807983
# 13       66.057551          81.222432               73.639992
# 14       66.680064          81.933280               74.306672
#
#            Size Group
# 0        Small(<1000)
# 1        Small(<1000)
# 2   Medium(1000-2000)
# 3   Medium(1000-2000)
# 4   Medium(1000-2000)
# 5   Medium(1000-2000)
# 6   Medium(1000-2000)
# 7    Large(2000-5000)
# 8    Large(2000-5000)
# 9    Large(2000-5000)
# 10   Large(2000-5000)
# 11   Large(2000-5000)
# 12   Large(2000-5000)
# 13   Large(2000-5000)
# 14   Large(2000-5000)

# %%
school_size2 = school_size.groupby('Size Group')["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing Rate"].mean()
school_size2.head()
# Out:
#                    Average Math Score  Average Reading Score  % Passing Math  \
# Size Group
# Small(<1000)                83.821598              83.929843       93.550225
# Medium(1000-2000)           83.374684              83.864438       93.599695
# Large(2000-5000)            77.746417              81.344493       69.963361
#
#                    % Passing Reading  % Overall Passing Rate
# Size Group
# Small(<1000)               96.099437               94.824831
# Medium(1000-2000)          96.790680               95.195187
# Large(2000-5000)           82.766634               76.364998
